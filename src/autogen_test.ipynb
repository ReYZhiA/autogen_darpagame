# %%
import json
import re
import pandas as pd

from IPython import get_ipython
from typing_extensions import Annotated

import autogen
from autogen import Agent, GroupChat
from autogen.cache import Cache
from dragonTextEnv import DragonTextEnv

config_list = autogen.config_list_from_json(
    "./OAI_CONFIG_LIST",
    filter_dict={"tags": ["tool"]},  # comment out to get all
)


local_llm_config = {
    "config_list": [
        {
            "model": "NotRequired",  # Loaded with LiteLLM command
            "api_key": "NotRequired",  # Not needed
            "base_url": "http://0.0.0.0:4000",  # Your LiteLLM URL
            "price": [0, 0],  # Put in price per 1K tokens [prompt, response] as free!
        }
    ],
    "cache_seed": None,  # Turns off caching, useful for testing different models
}

# %%
config_list
# Out:
# [{'model': 'gpt-4-turbo',
#   'api_key': 'sk-proj-kqnj8T68RcoSelw4iqYOT3BlbkFJ0G9juPPk2du3FvdlTbro',
#   'tags': ['gpt-4-turbo', 'tool']},
#  {'model': 'gpt-4o-2024-08-06',
#   'api_key': 'sk-proj-kqnj8T68RcoSelw4iqYOT3BlbkFJ0G9juPPk2du3FvdlTbro',
#   'tags': ['gpt-4o-snapshot', 'tool']},
#  {'model': 'gpt-4o-mini',
#   'api_key': 'sk-proj-kqnj8T68RcoSelw4iqYOT3BlbkFJ0G9juPPk2du3FvdlTbro',
#   'tags': ['gpt-4o-mini', 'tool']}]

# %%
env = DragonTextEnv(
    seed=42,
    include_agent_action=True,
    allow_comm=True,
    act_and_comm=True,
    tool_per_agent=2,
)

# %%
background_prompt_agent = "Welcome to our interactive text game! In this game, you'll assume the role of a specialist on a search and rescue team. Alongside two other players, you'll navigate a five-room environment with a mission to defuse five hidden bombs. Your call sign is {agent_id}\
The Map: Imagine a network of rooms represented by a connected graph where each node corresponds to a room, and the edges between nodes depict hallways. The rooms are numbered 0, 3, 6, 5, and 8. Room 0 is connected to all other rooms. Room 5 shares a hallway with room 6. Room 3 is linked to room 8. And room 8 is also connected with room 6. You can only travel to adjacent, directly connected rooms at each turn.\
The Challenge: Scattered among these rooms are five bombs, each coded with different phases represented by colors. To defuse them, you'll need to use the correct wire-cutting tools in the correct sequence. There are one-phase, two-phase, and three-phase bombs, needing 1, 2, or 3 color-coded tool applications in sequence to disarm. For instance, a bomb with a red-green phase sequence requires the red tool first, then the green one. Points are awarded based on the number of tools used for defusing a bomb, with each tool use worth 10 points. Your task is to maximize the team score as soon as possible. The challenge is that the bomb locations and sequences are unknown to players at the start.\
Tools: Each player is equipped with two color-coded wire cutters. Player Alpha has red and green tools, player Bravo wields green and blue, and player Charlie possesses blue and red.\
Actions: Each round, you can opt to do one of the following: 1) Move to an adjacent room, 2) Inspect a bomb's phase sequence in your current room, or 3) Apply your wire cutters to a bomb in the current room. \
Communications: In addition to selecting an action to take from the above list, you can also send communication message texts to both of your teammates in each round. The message text you sent will be shared with both of your teammates in their observation in the next round. \
Observation: While you can only see what's in your current room and read text messages from teammates. You'll also be informed of the current round number, team score and the current location of your teammates. Your teammates have the same observability as you. They will not be able to know your action and its consequences unless you explicitly communicate. \
You will be playing as Player {agent_id}. To facilitate our interaction, reply your action selection and communication messages in this fixed format: Action selection: Your action. Message to Team: “Your Message”. To move to an adjacent room, say: 'Move to Room X'. To inspect the sequence of a bomb in your current room, say: 'Inspect Bomb'. To apply a wire cutter tool, say: 'Apply X Tool'. Remember, your replies must adhere strictly to these rules. Feel free to ask clarifying questions if needed. I'll supply the necessary information as we progress. Are you ready to take on this explosive challenge?"

# %%
background_prompt_manager = """Welcome to the Search and Rescue Operations Command Center! As the Group Manager, your main responsibility is to provide strategic oversight with concise communication at the beginning and end of each round.

Mission Brief: Guide the team to locate and defuse five hidden bombs that are scattered in unknown rooms. Provide 'Round X Starting' and 'Round X Summary' messages.

Bomb Defusal: The exact positions of the bombs are unknown and must be discovered through inspection and room exploration. There are one-phase, two-phase, and three-phase bombs needing specific tool sequences. Alpha has red and green tools, Bravo has green and blue tools, Charlie has blue and red tools.

Responsibilities:
1. Start each round with a brief 'Round X Starting' message outlining the current situation and any key updates.
2. After agents select their actions, send a 'Round X Summary' recalling agents' choices and summarizing progress.

Action Protocol: Facilitate communication among agents to ensure they coordinate effectively on room inspections, bomb identification, and tool application.

Scoring: Aim to maximize the team score by efficiently defusing bombs with minimal tool use.

Readiness Check: Ensure agents understand the strategy and objectives before starting."""

# %%
# background_prompt_manager = """Welcome to the Search and Rescue Operations Command Center! As the Group Manager, your main responsibility is to provide strategic oversight with concise communication at the beginning and end of each round.

# Mission Brief: Guide the team to locate and defuse five hidden bombs that are scattered in unknown rooms. Provide 'Round X Starting' and 'Round X Summary' messages.

# Bomb Defusal: The exact positions of the bombs are unknown and must be discovered through inspection and room exploration. There are one-phase, two-phase, and three-phase bombs needing specific tool sequences. Alpha has red and green tools, Bravo has green and blue tools, Charlie has blue and red tools.

# Responsibilities:
# 1. Start each round with a brief 'Round X Starting' message outlining the current situation and any key updates.
# 2. After agents select their actions, send a 'Round X Summary' recalling agents' choices and summarizing progress. Conclude with 'TERMINATE' without any other symbols.

# Action Protocol: Facilitate communication among agents to ensure they coordinate effectively on room inspections, bomb identification, and tool application.

# Scoring: Aim to maximize the team score by efficiently defusing bombs with minimal tool use.

# Game Information: Use round updates, team score, player positions, and agents' actions to inform your messages.

# Readiness Check: Ensure agents understand the strategy and objectives before starting."""

# %%
logging_session_id = autogen.runtime_logging.start(config={"dbname": "logs.db"})
print("Logging session ID: " + str(logging_session_id))
# Out:
# Logging session ID: 118c5dd0-821a-4b5e-bade-653c6023c463

# %%
from pydantic import BaseModel


class DragonExpExtraction(BaseModel):
    agents_names: list[str]
    agents_actions: list[str]
    agents_comm: list[str]

# %%
from openai import OpenAI
import inspect

openai_kwargs = set(inspect.getfullargspec(OpenAI.__init__).kwonlyargs)
print(openai_kwargs)
# Out:
# {'base_url', 'api_key', 'timeout', 'http_client', 'default_query', 'default_headers', '_strict_response_validation', 'max_retries', 'organization', 'project'}

# %%
llm_config = {
    "temperature": 0,
    "timeout": 120,
    "config_list": config_list,
}

formatter_config = {
    "temperature": 0,
    "timeout": 120,
    "config_list": config_list,
    # "response_format": DragonExpExtraction,  # TODO for structured outputs
}
nb_agents = 3
codenames = [
    "alpha",
    "bravo",
    "charlie",
    "delta",
    "echo",
    "foxtrot",
    "golf",
    "hotel",
    "india",
    "juliett",
]


def terminate_message(x):
    tv = x.get("content", "") and (
        x.get("content", "").rstrip().endswith("TERMINATE")
        or re.search(r"Round \d+ Summary$", x.get("content", "").rstrip() is not None)
    )
    return tv


agents = []
for _, codename in enumerate(codenames[:nb_agents]):
    name = f"agent_{codename}"
    print(name)
    globals()[name] = autogen.AssistantAgent(
        name=name,
        llm_config=llm_config,
        system_message=background_prompt_agent.format(agent_id=codename),
        description=f"Agent {codename} is a specialist on a search and defuse team.",
    )
    agents.append(globals()[name])

agent_manager = autogen.AssistantAgent(
    name="agent_manager",
    llm_config=llm_config,
    system_message=background_prompt_manager,
    description="The Manager of the Search and Defuse Operations Command Center",
)
agents.append(agent_manager)

# create a UserProxyAgent instance named "user_proxy"
user_proxy = autogen.UserProxyAgent(
    name="user_proxy",
    is_termination_msg=lambda x: x.get("content", "")
    and x.get("content", "").rstrip().endswith("TERMINATE"),
    human_input_mode="NEVER",
    max_consecutive_auto_reply=10,
    code_execution_config={"work_dir": "coding", "use_docker": True},
)

agents.append(user_proxy)

formatter = autogen.AssistantAgent(
    name="formatter",
    llm_config=formatter_config,
    description="Formatter to extract experiment data",
    system_message="""You are a formatter that should report the actions and communications of the operative agents only, agent_manager not being one. The actions must be reported in the format :\
        {agents_names: list[str],
            agents_actions: list[str],
            agents_comm: list[str]}
        agents_names should be in lowercase with no spaces.
        agents_actions should be one of the following: 'go_to_node_X', 'inspect_bomb', 'apply_X_tool'.
        Answer "TERMINATE" after your task is done.""",
)

agents.append(formatter)
# Out:
# agent_alpha
# agent_bravo
# agent_charlie

# %%
messages = []


def custom_speaker_selection_func(last_speaker: Agent, groupchat: GroupChat):
    """Define a customized speaker selection function.
    A recommended way is to define a transition for each speaker in the groupchat.

    Returns:
        Return an `Agent` class or a string from ['auto', 'manual', 'random', 'round_robin'] to select a default method to use.
    """
    globals()["messages"] = groupchat.messages
    if len(messages) <= 1:
        print("Selecting agent_manager")
        return agent_manager

    if (
        re.search(r"Round \w+ Summary:?", messages[-1].get("content", "").rstrip())
        is not None
    ):
        return formatter

    elif last_speaker is formatter:
        return user_proxy

    else:
        return "auto"

# %%
groupchat = autogen.GroupChat(
    agents=agents,
    messages=[],
    max_round=10,
    speaker_selection_method=custom_speaker_selection_func,  # TODO needs tuning to properly give the manager the first turn and formatter the last
)
gc_manager = autogen.GroupChatManager(
    name="groupchat_manager",
    groupchat=groupchat,
    llm_config=llm_config,
    is_termination_msg=lambda x: x.get("content", "")
    and x.get("content", "").rstrip().endswith("TERMINATE"),
)

# %%
with Cache.disk() as cache:
    user_proxy.initiate_chat(
        gc_manager,
        message="Agent_manager initiates a new game session and agents procede to play the game.",
    )
# Out:
# user_proxy (to groupchat_manager):
#
# Agent_manager initiates a new game session and agents procede to play the game.
#
# --------------------------------------------------------------------------------
# Selecting agent_manager
#
# Next speaker: agent_manager
#
# agent_manager (to groupchat_manager):
#
# Round 1 Starting:
# Welcome, team. Our mission is to locate and defuse five hidden bombs scattered across various rooms. Each agent has specific tools, so coordination is crucial. Let's start by exploring and inspecting rooms to identify the bombs. Stay alert and communicate effectively. Good luck, everyone. Let's begin the operation.
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_alpha
#
# agent_alpha (to groupchat_manager):
#
# Action selection: Move to Room 3.
# Message to Team: “Heading to Room 3 to check for bombs. Let's spread out and inspect different rooms. Report any bomb sequences you find.”
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_bravo
#
# agent_bravo (to groupchat_manager):
#
# Action selection: Move to Room 5.
# Message to Team: “Moving to Room 5 to search for bombs. Will update if I find anything. Let's keep the communication open.”
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_charlie
#
# agent_charlie (to groupchat_manager):
#
# Action selection: Move to Room 6.
# Message to Team: “I'm going to Room 6 to look for bombs. Let's coordinate our findings and tool uses efficiently.”
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_manager
#
# agent_manager (to groupchat_manager):
#
# Round 1 Summary:
# - Agent Alpha moved to Room 3 and is currently inspecting for bombs.
# - Agent Bravo proceeded to Room 5 to search for any hidden bombs.
# - Agent Charlie is exploring Room 6 for bomb detection.
#
# All agents have spread out to cover different areas, maximizing our search efficiency. Keep up the good communication and report back any findings or bomb sequences. Let's prepare for the next round of actions based on the information gathered.
#
# --------------------------------------------------------------------------------
#
# Next speaker: formatter
#
# formatter (to groupchat_manager):
#
# {
#     "agents_names": ["agent_alpha", "agent_bravo", "agent_charlie"],
#     "agents_actions": ["go_to_node_3", "go_to_node_5", "go_to_node_6"],
#     "agents_comm": [
#         "Heading to Room 3 to check for bombs. Let's spread out and inspect different rooms. Report any bomb sequences you find.",
#         "Moving to Room 5 to search for bombs. Will update if I find anything. Let's keep the communication open.",
#         "I'm going to Room 6 to look for bombs. Let's coordinate our findings and tool uses efficiently."
#     ]
# }
# TERMINATE
#
# --------------------------------------------------------------------------------

# %%
autogen.runtime_logging.stop()

# %% [markdown]
# ### Logging processing

# %%
def get_log(dbname="logs.db", table="chat_completions"):
    import sqlite3

    con = sqlite3.connect(dbname)
    query = f"SELECT * from {table}"
    cursor = con.execute(query)
    rows = cursor.fetchall()
    column_names = [description[0] for description in cursor.description]
    data = [dict(zip(column_names, row)) for row in rows]
    con.close()
    return data

# %%
def str_to_dict(s):
    return json.loads(s)


log_data = get_log()
log_data_df = pd.DataFrame(log_data)

log_data_df["total_tokens"] = log_data_df.apply(
    lambda row: str_to_dict(row["response"])["usage"]["total_tokens"], axis=1
)

log_data_df["request"] = log_data_df.apply(
    lambda row: str_to_dict(row["request"])["messages"][0]["content"], axis=1
)

log_data_df["response"] = log_data_df.apply(
    lambda row: str_to_dict(row["response"])["choices"][0]["message"]["content"], axis=1
)

log_data_df
# Out:
#     id                         invocation_id        client_id  \
# 0    1  27ce45ea-077c-41d5-a80f-307f45c7c5b6  126558296521120
# 1    2  aea63ab3-4b3e-4a8b-bdff-eb7d0dd113b1  126558296030464
# 2    3  ae8e0f9b-1b5b-4881-815a-77ae7ca25f99  126558297086224
# 3    4  98b5771f-2cbc-4ed9-ae5e-ecb8970e13c0  126558295662848
# 4    5  2de280cc-0b84-4409-bb22-c076a1ad4348  126558296628816
# 5    6  343ab784-644a-438a-b025-41d22ce4ebad  126558295789680
# 6    7  4bed783e-ca69-4dd3-9aef-42b10f1ec306  126558296398864
# 7    8  7ac4cb5b-2c5b-4acd-8141-625fddbab491  126558295792272
# 8    9  3a39badf-07bb-49f4-92b1-0ba4838b45ae  126558296521120
# 9   10  51109fec-f604-4b08-9086-c0dd22cd8f20  126558296275792
# 10  11  f792e184-549b-4bfa-bdc7-db1b03577f0c  138708540889648
# 11  12  bb450924-bc60-4f74-ab68-e696db6c0c73  138708540398992
# 12  13  1de71b51-1c76-49b5-b2f6-6a9ff21b2246  138708541495280
# 13  14  eea8fb38-90d8-4b18-b0df-0a9981ef88d2  138708540023184
# 14  15  b32b786e-0121-4979-b0d9-1639d6db515e  138708540993248
# 15  16  1deb8a12-044e-4768-85eb-0e6361db2d14  138708540154112
# 16  17  06991b33-9e62-4b3b-a718-b27a71e09d15  138708540767392
# 17  18  7aaa7b75-9473-4fc3-89a9-45cd08f3fed1  138708540156704
# 18  19  ad7ea307-b7dd-45d2-b060-a7809fa66dfc  138708540889648
# 19  20  fbdf2cba-d182-4465-ae6c-36f9c6a568d4  138708540640224
# 20  21  f5fc1346-3f20-4cbb-9831-eb8235c17768  134863895550320
# 21  22  7901abe1-008f-4528-ae4a-cac857d00122  134863895063760
# 22  23  06824fce-1ac3-47ae-ad92-b1cc1a55f5a5  134863896016640
# 23  24  d177c89e-c269-4c8d-9af3-10c781965681  134863698858192
# 24  25  d760d6cb-76f6-461f-a239-6e342c3e0817  134863895858720
# 25  26  ed1148b2-d203-4216-a451-f85dd17bdfc2  134863895021360
# 26  27  8564a6b4-550d-408a-b69d-b98ffe8a9d73  134863895423968
# 27  28  50821386-2b12-4945-a041-5286b95916ee  134863698982752
# 28  29  5a356b61-0ab6-45f0-a885-b27207b73de7  134863895550320
# 29  30  97311613-2193-4b6b-96f9-b1aaee1a62f8  134863895304992
# 30  31  0cde7422-18e2-43a2-a7bd-cac0cf457d9a  136083383421296
# 31  32  87951beb-3232-4d27-8953-7d33944e8124  136083382922448
# 32  33  57c769c0-d111-4b7a-ad3b-ac5a53e12f67  136083383908528
# 33  34  ca4c0f10-d9a1-484e-869e-9eb4e578fa8d  136083382550736
# 34  35  41410807-b674-40c1-ab2e-c0695b7087ac  136083383610912
# 35  36  2c0fd609-af08-4401-9e16-fb91710dd2c6  136083382681664
# 36  37  4f8e5bce-091a-430a-85d3-f4dae14505b8  136083383294944
# 37  38  97761692-84c9-44ee-b379-3abe62678157  136083382631872
# 38  39  88dc9385-a6df-4e51-a7fb-454710e28160  136083383421296
# 39  40  c64d9ed1-092e-4b34-96ed-dc132768de36  136083383171872
# 40  41  52192041-1d44-4b5b-a5c3-9dd34fe786c0  136947015256672
# 41  42  096220cc-abb2-475b-a21f-a77f349eafd5  136946818932112
# 42  43  13684104-d168-4713-a660-5b6f8fcfc4d4  136947015723952
# 43  44  9d405ef9-f658-4e20-862c-51580bb4ac29  136946818568592
# 44  45  c64df4de-1f21-4f0e-b5cd-0d0448ad5bd9  136947015413520
# 45  46  c338196c-b6ef-46b4-bd00-a2eb44b60a15  136946818699520
# 46  47  42f606cd-d176-45d0-a554-3efaca4c7afc  136947015138512
# 47  48  1976bfb6-83aa-46c1-a900-f7f5c33c76c4  136946818569792
# 48  49  3a91a9a6-4484-4f74-83bc-71909ad5f71f  136947015256672
# 49  50  b12417ed-70ea-4bcc-bc19-5d925d50d052  136947015015392
# 50  51  011d2df3-9a49-402e-9b78-3bf9eb082437  126707192732016
# 51  52  649fb3b8-2082-4014-b463-3725644803e5  126707192233120
# 52  53  0e56c184-0555-42d4-aa08-a000acf2a2e1  126707193341888
# 53  54  afef421f-05cd-49a0-a2e0-ede715ded897  126706924736672
# 54  55  695a9e81-b746-4426-af10-b8a3ad296ed7  126707192917536
# 55  56  ff11320b-ca5d-4f0f-9757-5761331e6532  126706924842960
# 56  57  25936ce9-d48c-4c42-b390-bb2b7361644b  126707192613856
# 57  58  86d81e29-49d2-4917-b903-74d4a3e61b84  126706924841280
# 58  59  fa8fd277-e0aa-434a-af65-b29ef43d632d  126707192732016
# 59  60  55d4fd43-ef20-49ab-9187-f32c905b4e3f  126707192482544
#
#          wrapper_id                            session_id  \
# 0   126558296813376  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 1   126558295915392  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 2   126558297100688  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 3   126558295586848  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 4   126558297100832  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 5   126558295721872  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 6   126563592232816  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 7   126558295312512  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 8   126558296813376  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 9   126558297100736  7dde265c-0b6b-465c-a2c5-b757f7f166f3
# 10  138708541112384  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 11  138708540280256  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 12  138708540994128  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 13  138708539951184  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 14  138708540994224  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 15  138708539951568  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 16  138708541104080  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 17  138708539672656  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 18  138708541112384  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 19  138708540993984  83643ee3-4242-430c-879e-8cc0ca7a13a5
# 20  134863895797712  c654f2ff-b651-4abc-b835-5acce04a7ace
# 21  134863894952688  c654f2ff-b651-4abc-b835-5acce04a7ace
# 22  134869191397968  c654f2ff-b651-4abc-b835-5acce04a7ace
# 23  134863895020736  c654f2ff-b651-4abc-b835-5acce04a7ace
# 24  134869191401376  c654f2ff-b651-4abc-b835-5acce04a7ace
# 25  134863895123616  c654f2ff-b651-4abc-b835-5acce04a7ace
# 26  134869191400368  c654f2ff-b651-4abc-b835-5acce04a7ace
# 27  134863895124336  c654f2ff-b651-4abc-b835-5acce04a7ace
# 28  134863895797712  c654f2ff-b651-4abc-b835-5acce04a7ace
# 29  134869191397824  c654f2ff-b651-4abc-b835-5acce04a7ace
# 30  136083383529424  54ad02d3-b329-4739-ace3-a8e38837ac77
# 31  136083382824000  54ad02d3-b329-4739-ace3-a8e38837ac77
# 32  136083383517488  54ad02d3-b329-4739-ace3-a8e38837ac77
# 33  136083382483120  54ad02d3-b329-4739-ace3-a8e38837ac77
# 34  136083383517584  54ad02d3-b329-4739-ace3-a8e38837ac77
# 35  136083382614576  54ad02d3-b329-4739-ace3-a8e38837ac77
# 36  136083384365008  54ad02d3-b329-4739-ace3-a8e38837ac77
# 37  136083382724688  54ad02d3-b329-4739-ace3-a8e38837ac77
# 38  136083383529424  54ad02d3-b329-4739-ace3-a8e38837ac77
# 39  136083383517248  54ad02d3-b329-4739-ace3-a8e38837ac77
# 40  136947015467120  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 41  136946818841904  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 42  136947015844672  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 43  136946818492496  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 44  136947015844816  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 45  136946818632432  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 46  136947015892656  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 47  136946818611232  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 48  136947015467120  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 49  136947015844480  ab52dd0b-9028-44ce-b6dc-f98219d4a2f9
# 50  126707192831952  118c5dd0-821a-4b5e-bade-653c6023c463
# 51  126707192138816  118c5dd0-821a-4b5e-bade-653c6023c463
# 52  126707192861168  118c5dd0-821a-4b5e-bade-653c6023c463
# 53  126707192210336  118c5dd0-821a-4b5e-bade-653c6023c463
# 54  126707192864336  118c5dd0-821a-4b5e-bade-653c6023c463
# 55  126706924804608  118c5dd0-821a-4b5e-bade-653c6023c463
# 56  126712221655488  118c5dd0-821a-4b5e-bade-653c6023c463
# 57  126706924910672  118c5dd0-821a-4b5e-bade-653c6023c463
# 58  126707192831952  118c5dd0-821a-4b5e-bade-653c6023c463
# 59  126707192861024  118c5dd0-821a-4b5e-bade-653c6023c463
#
#                 source_name  \
# 0             agent_manager
# 1   speaker_selection_agent
# 2               agent_alpha
# 3   speaker_selection_agent
# 4               agent_bravo
# 5   speaker_selection_agent
# 6             agent_charlie
# 7   speaker_selection_agent
# 8             agent_manager
# 9                 formatter
# 10            agent_manager
# 11  speaker_selection_agent
# 12              agent_alpha
# 13  speaker_selection_agent
# 14              agent_bravo
# 15  speaker_selection_agent
# 16            agent_charlie
# 17  speaker_selection_agent
# 18            agent_manager
# 19                formatter
# 20            agent_manager
# 21  speaker_selection_agent
# 22              agent_alpha
# 23  speaker_selection_agent
# 24              agent_bravo
# 25  speaker_selection_agent
# 26            agent_charlie
# 27  speaker_selection_agent
# 28            agent_manager
# 29                formatter
# 30            agent_manager
# 31  speaker_selection_agent
# 32              agent_alpha
# 33  speaker_selection_agent
# 34              agent_bravo
# 35  speaker_selection_agent
# 36            agent_charlie
# 37  speaker_selection_agent
# 38            agent_manager
# 39                formatter
# 40            agent_manager
# 41  speaker_selection_agent
# 42              agent_alpha
# 43  speaker_selection_agent
# 44              agent_bravo
# 45  speaker_selection_agent
# 46            agent_charlie
# 47  speaker_selection_agent
# 48            agent_manager
# 49                formatter
# 50            agent_manager
# 51  speaker_selection_agent
# 52              agent_alpha
# 53  speaker_selection_agent
# 54              agent_bravo
# 55  speaker_selection_agent
# 56            agent_charlie
# 57  speaker_selection_agent
# 58            agent_manager
# 59                formatter
#
#                                               request  \
# 0   Welcome to the Search and Rescue Operations Co...
# 1   You are in a role play game. The following rol...
# 2   Welcome to our interactive text game! In this ...
# 3   You are in a role play game. The following rol...
# 4   Welcome to our interactive text game! In this ...
# 5   You are in a role play game. The following rol...
# 6   Welcome to our interactive text game! In this ...
# 7   You are in a role play game. The following rol...
# 8   Welcome to the Search and Rescue Operations Co...
# 9   You are a formatter that should report the act...
# 10  Welcome to the Search and Rescue Operations Co...
# 11  You are in a role play game. The following rol...
# 12  Welcome to our interactive text game! In this ...
# 13  You are in a role play game. The following rol...
# 14  Welcome to our interactive text game! In this ...
# 15  You are in a role play game. The following rol...
# 16  Welcome to our interactive text game! In this ...
# 17  You are in a role play game. The following rol...
# 18  Welcome to the Search and Rescue Operations Co...
# 19  You are a formatter that should report the act...
# 20  Welcome to the Search and Rescue Operations Co...
# 21  You are in a role play game. The following rol...
# 22  Welcome to our interactive text game! In this ...
# 23  You are in a role play game. The following rol...
# 24  Welcome to our interactive text game! In this ...
# 25  You are in a role play game. The following rol...
# 26  Welcome to our interactive text game! In this ...
# 27  You are in a role play game. The following rol...
# 28  Welcome to the Search and Rescue Operations Co...
# 29  You are a formatter that should report the act...
# 30  Welcome to the Search and Rescue Operations Co...
# 31  You are in a role play game. The following rol...
# 32  Welcome to our interactive text game! In this ...
# 33  You are in a role play game. The following rol...
# 34  Welcome to our interactive text game! In this ...
# 35  You are in a role play game. The following rol...
# 36  Welcome to our interactive text game! In this ...
# 37  You are in a role play game. The following rol...
# 38  Welcome to the Search and Rescue Operations Co...
# 39  You are a formatter that should report the act...
# 40  Welcome to the Search and Rescue Operations Co...
# 41  You are in a role play game. The following rol...
# 42  Welcome to our interactive text game! In this ...
# 43  You are in a role play game. The following rol...
# 44  Welcome to our interactive text game! In this ...
# 45  You are in a role play game. The following rol...
# 46  Welcome to our interactive text game! In this ...
# 47  You are in a role play game. The following rol...
# 48  Welcome to the Search and Rescue Operations Co...
# 49  You are a formatter that should report the act...
# 50  Welcome to the Search and Rescue Operations Co...
# 51  You are in a role play game. The following rol...
# 52  Welcome to our interactive text game! In this ...
# 53  You are in a role play game. The following rol...
# 54  Welcome to our interactive text game! In this ...
# 55  You are in a role play game. The following rol...
# 56  Welcome to our interactive text game! In this ...
# 57  You are in a role play game. The following rol...
# 58  Welcome to the Search and Rescue Operations Co...
# 59  You are a formatter that should report the act...
#
#                                              response  is_cached     cost  \
# 0   Round 1 Starting:\nWelcome, team. Our mission ...          1  0.00469
# 1                                         agent_alpha          1  0.00335
# 2   Action selection: Move to Room 3.\nMessage to ...          1  0.00874
# 3                                         agent_bravo          1  0.00385
# 4   Action selection: Move to Room 5.\nMessage to ...          1  0.00917
# 5                                       agent_charlie          1  0.00431
# 6   Action selection: Move to Room 6.\nMessage to ...          1  0.00957
# 7                                       agent_manager          1  0.00472
# 8   Round 1 Summary:\n- Agent Alpha moved to Room ...          1  0.00752
# 9   {\n    agents_names: ["Agent_manager", "Agent_...          0  0.01104
# 10  Round 1 Starting:\nWelcome, team. Our mission ...          1  0.00469
# 11                                        agent_alpha          1  0.00335
# 12  Action selection: Move to Room 3.\nMessage to ...          1  0.00874
# 13                                        agent_bravo          1  0.00385
# 14  Action selection: Move to Room 5.\nMessage to ...          1  0.00917
# 15                                      agent_charlie          1  0.00431
# 16  Action selection: Move to Room 6.\nMessage to ...          1  0.00957
# 17                                      agent_manager          1  0.00472
# 18  Round 1 Summary:\n- Agent Alpha moved to Room ...          1  0.00752
# 19  {\n    "agents_names": ["Agent_manager", "Agen...          0  0.01376
# 20  Round 1 Starting:\nWelcome, team. Our mission ...          1  0.00469
# 21                                        agent_alpha          1  0.00335
# 22  Action selection: Move to Room 3.\nMessage to ...          1  0.00874
# 23                                        agent_bravo          1  0.00385
# 24  Action selection: Move to Room 5.\nMessage to ...          1  0.00917
# 25                                      agent_charlie          1  0.00431
# 26  Action selection: Move to Room 6.\nMessage to ...          1  0.00957
# 27                                      agent_manager          1  0.00472
# 28  Round 1 Summary:\n- Agent Alpha moved to Room ...          1  0.00752
# 29  {\n    "agents_names": ["Agent Alpha", "Agent ...          0  0.00809
# 30  Round 1 Starting:\nWelcome, team. Our mission ...          1  0.00469
# 31                                        agent_alpha          1  0.00335
# 32  Action selection: Move to Room 3.\nMessage to ...          1  0.00874
# 33                                        agent_bravo          1  0.00385
# 34  Action selection: Move to Room 5.\nMessage to ...          1  0.00917
# 35                                      agent_charlie          1  0.00431
# 36  Action selection: Move to Room 6.\nMessage to ...          1  0.00957
# 37                                      agent_manager          1  0.00472
# 38  Round 1 Summary:\n- Agent Alpha moved to Room ...          1  0.00752
# 39  {\n    "agents_names": ["agent_alpha", "agent_...          0  0.00852
# 40  Round 1 Starting:\nWelcome, team. Our mission ...          1  0.00469
# 41                                        agent_alpha          1  0.00335
# 42  Action selection: Move to Room 3.\nMessage to ...          1  0.00874
# 43                                        agent_bravo          1  0.00385
# 44  Action selection: Move to Room 5.\nMessage to ...          1  0.00917
# 45                                      agent_charlie          1  0.00431
# 46  Action selection: Move to Room 6.\nMessage to ...          1  0.00957
# 47                                      agent_manager          1  0.00472
# 48  Round 1 Summary:\n- Agent Alpha moved to Room ...          1  0.00752
# 49  {\n    "agents_names": ["agent_alpha", "agent_...          1  0.00852
# 50  Round 1 Starting:\nWelcome, team. Our mission ...          1  0.00469
# 51                                        agent_alpha          1  0.00335
# 52  Action selection: Move to Room 3.\nMessage to ...          1  0.00874
# 53                                        agent_bravo          1  0.00385
# 54  Action selection: Move to Room 5.\nMessage to ...          1  0.00917
# 55                                      agent_charlie          1  0.00431
# 56  Action selection: Move to Room 6.\nMessage to ...          1  0.00957
# 57                                      agent_manager          1  0.00472
# 58  Round 1 Summary:\n- Agent Alpha moved to Room ...          1  0.00752
# 59  {\n    "agents_names": ["agent_alpha", "agent_...          1  0.00852
#
#                     start_time                    end_time  total_tokens
# 0   2024-08-21 07:13:24.293604  2024-08-21 07:13:24.293902           335
# 1   2024-08-21 07:13:24.351304  2024-08-21 07:13:24.351541           331
# 2   2024-08-21 07:13:24.365694  2024-08-21 07:13:24.366049           794
# 3   2024-08-21 07:13:24.415190  2024-08-21 07:13:24.415366           379
# 4   2024-08-21 07:13:24.428711  2024-08-21 07:13:24.428889           841
# 5   2024-08-21 07:13:24.479043  2024-08-21 07:13:24.479201           425
# 6   2024-08-21 07:13:24.503811  2024-08-21 07:13:24.504294           885
# 7   2024-08-21 07:13:24.552549  2024-08-21 07:13:24.552690           468
# 8   2024-08-21 07:13:24.565662  2024-08-21 07:13:24.565824           568
# 9   2024-08-21 07:13:24.588047  2024-08-21 07:13:32.376801           636
# 10  2024-08-21 07:30:43.705171  2024-08-21 07:30:43.705413           335
# 11  2024-08-21 07:30:43.765436  2024-08-21 07:30:43.765672           331
# 12  2024-08-21 07:30:43.783115  2024-08-21 07:30:43.783322           794
# 13  2024-08-21 07:30:43.836438  2024-08-21 07:30:43.836615           379
# 14  2024-08-21 07:30:43.853308  2024-08-21 07:30:43.853677           841
# 15  2024-08-21 07:30:43.911636  2024-08-21 07:30:43.911840           425
# 16  2024-08-21 07:30:43.939781  2024-08-21 07:30:43.940225           885
# 17  2024-08-21 07:30:43.997343  2024-08-21 07:30:43.997504           468
# 18  2024-08-21 07:30:44.013378  2024-08-21 07:30:44.013683           568
# 19  2024-08-21 07:30:44.036426  2024-08-21 07:30:55.420556           726
# 20  2024-08-21 07:31:44.022188  2024-08-21 07:31:44.022478           335
# 21  2024-08-21 07:31:44.076465  2024-08-21 07:31:44.076613           331
# 22  2024-08-21 07:31:44.090755  2024-08-21 07:31:44.090938           794
# 23  2024-08-21 07:31:44.145431  2024-08-21 07:31:44.145758           379
# 24  2024-08-21 07:31:44.159517  2024-08-21 07:31:44.159870           841
# 25  2024-08-21 07:31:44.209893  2024-08-21 07:31:44.210065           425
# 26  2024-08-21 07:31:44.224099  2024-08-21 07:31:44.224250           885
# 27  2024-08-21 07:31:44.278016  2024-08-21 07:31:44.278182           468
# 28  2024-08-21 07:31:44.292338  2024-08-21 07:31:44.292489           568
# 29  2024-08-21 07:31:44.312846  2024-08-21 07:31:50.401958           541
# 30  2024-08-21 07:37:50.991760  2024-08-21 07:37:50.991967           335
# 31  2024-08-21 07:37:51.047552  2024-08-21 07:37:51.048015           331
# 32  2024-08-21 07:37:51.064384  2024-08-21 07:37:51.064769           794
# 33  2024-08-21 07:37:51.124887  2024-08-21 07:37:51.125045           379
# 34  2024-08-21 07:37:51.145532  2024-08-21 07:37:51.145929           841
# 35  2024-08-21 07:37:51.209468  2024-08-21 07:37:51.209824           425
# 36  2024-08-21 07:37:51.235695  2024-08-21 07:37:51.236157           885
# 37  2024-08-21 07:37:51.291834  2024-08-21 07:37:51.292198           468
# 38  2024-08-21 07:37:51.307193  2024-08-21 07:37:51.307346           568
# 39  2024-08-21 07:37:51.330577  2024-08-21 07:37:58.137311           580
# 40  2024-08-23 00:13:49.316508  2024-08-23 00:13:49.318980           335
# 41  2024-08-23 00:13:49.367613  2024-08-23 00:13:49.368549           331
# 42  2024-08-23 00:13:49.382209  2024-08-23 00:13:49.382589           794
# 43  2024-08-23 00:13:49.430341  2024-08-23 00:13:49.430471           379
# 44  2024-08-23 00:13:49.443802  2024-08-23 00:13:49.444363           841
# 45  2024-08-23 00:13:49.507074  2024-08-23 00:13:49.507568           425
# 46  2024-08-23 00:13:49.523689  2024-08-23 00:13:49.524150           885
# 47  2024-08-23 00:13:49.576293  2024-08-23 00:13:49.576451           468
# 48  2024-08-23 00:13:49.590358  2024-08-23 00:13:49.590504           568
# 49  2024-08-23 00:13:49.609719  2024-08-23 00:13:49.609950           580
# 50  2024-08-23 00:15:48.773010  2024-08-23 00:15:48.773197           335
# 51  2024-08-23 00:15:48.835943  2024-08-23 00:15:48.836510           331
# 52  2024-08-23 00:15:48.854099  2024-08-23 00:15:48.854495           794
# 53  2024-08-23 00:15:48.911624  2024-08-23 00:15:48.911966           379
# 54  2024-08-23 00:15:48.926492  2024-08-23 00:15:48.926747           841
# 55  2024-08-23 00:15:48.988548  2024-08-23 00:15:48.988745           425
# 56  2024-08-23 00:15:49.014711  2024-08-23 00:15:49.014893           885
# 57  2024-08-23 00:15:49.065882  2024-08-23 00:15:49.066047           468
# 58  2024-08-23 00:15:49.079520  2024-08-23 00:15:49.079706           568
# 59  2024-08-23 00:15:49.107107  2024-08-23 00:15:49.107448           580

# %% [markdown]
# ### Computing cost

# %%
# Sum total tokens for all sessions
try:
    total_tokens = log_data_df["total_tokens"].sum()
    # Total tokens for specific session
    session_tokens = log_data_df[log_data_df["session_id"] == logging_session_id][
        "total_tokens"
    ].sum()
except KeyError:
    total_tokens = "unknown"
    session_tokens = "unknown"

# Sum total cost for all sessions
total_cost = log_data_df["cost"].sum()


session_cost = log_data_df[log_data_df["session_id"] == logging_session_id][
    "cost"
].sum()

print(
    "Total tokens for all sessions: "
    + str(total_tokens)
    + ", total cost: "
    + str(round(total_cost, 4))
    + "$"
)
print(
    "Total tokens for session "
    + str(logging_session_id)
    + ": "
    + str(session_tokens)
    + ", cost: "
    + str(round(session_cost, 4))
    + "$"
)
# Out:
# Total tokens for all sessions: 33799, total cost: 0.394$
# Total tokens for session 118c5dd0-821a-4b5e-bade-653c6023c463: 5606, cost: 0.0644$

# %%
import json

data = json.loads(log_data_df.iloc[-1]["response"].replace("TERMINATE", ""))
data
# Out:
# {'agents_names': ['agent_alpha', 'agent_bravo', 'agent_charlie'],
#  'agents_actions': ['go_to_node_3', 'go_to_node_5', 'go_to_node_6'],
#  'agents_comm': ["Heading to Room 3 to check for bombs. Let's spread out and inspect different rooms. Report any bomb sequences you find.",
#   "Moving to Room 5 to search for bombs. Will update if I find anything. Let's keep the communication open.",
#   "I'm going to Room 6 to look for bombs. Let's coordinate our findings and tool uses efficiently."]}

# %%
actions = messages[-1].get("content", "").replace("TERMINATE", "")
json.loads(actions)
# Out:
# {'agents_names': ['agent_alpha', 'agent_bravo', 'agent_charlie'],
#  'agents_actions': ['go_to_node_3', 'go_to_node_5', 'go_to_node_6'],
#  'agents_comm': ["Heading to Room 3 to check for bombs. Let's spread out and inspect different rooms. Report any bomb sequences you find.",
#   "Moving to Room 5 to search for bombs. Will update if I find anything. Let's keep the communication open.",
#   "I'm going to Room 6 to look for bombs. Let's coordinate our findings and tool uses efficiently."]}
